# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
import io

import requests
import pandas as pd
import matplotlib.pyplot as plt

# transfer cutout data
r = requests.post(
  'https://fink-portal.org/api/v1/objects',
  json={
    'objectId': 'ZTF18acckcza',
    'withcutouts': 'True'
  }
)

# Format output in a DataFrame
pdf = pd.read_json(io.BytesIO(r.content))

columns = [
    'b:cutoutScience_stampData',
    'b:cutoutTemplate_stampData',
    'b:cutoutDifference_stampData'
]

for col in columns:
    # 2D array
    print()
    plt.figure()
    plt.subplot(1,2,1)
    data = pdf[col].values[0]
    plt.imshow(np.array(data))#[23:39,23:39])
    
    plt.subplot(1,2,2)
    data = pdf[col].values[2]
    plt.imshow(np.array(data))#[23:39,23:39])#[23:39,23:39])

    # do whatever plotting

plt.show()

# %%
pdf[['i:fid', 'i:distnr']]
# Out:
#     i:fid   i:distnr
# 0       1  10.623923
# 1       1  10.864206
# 2       2   0.962589
# 3       2   1.264779
# 4       2   1.241475
# 5       2   1.249515
# 6       2   1.047248
# 7       2   1.249208
# 8       2   1.013191
# 9       1  10.823056
# 10      1  10.610292
# 11      2   0.987600
# 12      2   0.977088
# 13      2   0.989195
# 14      2   1.268812
# 15      1  10.920635
# 16      2   0.918583
# 17      2   0.908654
# 18      2   0.933979
# 19      2   0.914698
# 20      2   1.449826
# 21      2   1.408168
# 22      2   1.285937
# 23      2   1.534409
# 24      2   1.358766
# 25      2   1.364672
# 26      2   1.336515
# 27      2   1.397928
# 28      2   1.486773
# 29      2   1.451909
# 30      2   1.435363
# 31      2   1.391473
# 32      1  10.878007
# 33      1  10.763827
# 34      2   1.031933
# 35      1  10.785479
# 36      1  10.654679
# 37      1  10.885915
# 38      1  10.777400
# 39      2   1.308173
# 40      2   1.394563
# 41      2   0.921603
# ...

# %%
for i in pdf.columns:
    print(i)
# Out:
# d:nalerthist
# i:ssmagnr
# i:magzpsciunc
# i:maggaiabright
# i:distpsnr2
# i:distpsnr3
# i:distpsnr1
# i:fink_broker_version
# i:pid
# i:dsnrms
# i:bimagerat
# i:chinr
# i:programpi
# i:candid
# d:rf_kn_vs_nonkn
# i:neargaiabright
# i:sigmagnr
# i:ranr
# i:diffmaglim
# i:elong
# i:pdiffimfilename
# i:ypos
# i:distnr
# i:objectidps1
# i:nneg
# i:ndethist
# i:objectidps2
# i:objectidps3
# i:exptime
# i:sigmapsf
# i:maggaia
# i:sumrat
# i:rfid
# i:aimagerat
# d:snn_sn_vs_all
# i:clrcounc
# i:sgmag1
# i:clrcoeff
# i:sgmag2
# d:roid
# i:sgmag3
# i:isdiffpos
# i:sgscore3
# i:sgscore1
# i:sgscore2
# i:srmag3
# i:schemavsn
# i:sky
# i:srmag2
# i:srmag1
# i:nmatches
# i:simag1
# i:simag2
# i:simag3
# i:programid
# i:jdstarthist
# i:fwhm
# i:drbversion
# i:chipsf
# i:dec
# i:jdstartref
# i:fid
# i:magnr
# i:ssnamenr
# i:nid
# i:sharpnr
# i:clrrms
# i:publisher
# i:field
# i:scorr
# i:sigmagap
# i:zpclrcov
# i:magfromlim
# d:cdsxmatch
# i:objectId
# i:clrmed
# i:ssnrms
# i:tooflag
# ...

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #
